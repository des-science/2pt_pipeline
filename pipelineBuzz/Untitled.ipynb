# %%
import numpy

# %%
import healpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-0afe7abe8d44> in <module>
# ----> 1 import healpy
#
# ModuleNotFoundError: No module named 'healpy'

# %%
import healpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0afe7abe8d44> in <module>
# ----> 1 import healpy
#
# ModuleNotFoundError: No module named 'healpy'
